# %% [markdown]
# # TUPLE

# %% [markdown]
# > 1. Tuple is a collection Data type Just Like a List, But it is a Immutable datatype(Not Changeble)
# > 2. Tuple cant be store Duplicates
# > 3. Tuple Literal is ()
# > 4. Tuple is Ordered.
# > 5. Tuple Store Multiple data Types Like List
# > 6. Tuple is Faster then List.

# %%
fruit=()  # empty Tuple

# %%
fruit=("Apple","Grapes","Banana",4,5,6)

# %%
fruit
# Out:
# ('Apple', 'Grapes', 'Banana', 4, 5, 6)

# %% [markdown]
# NESTED TUPLE

# %%
nested_tuple=(4,5,(5,6),(5,5,8,9,8),6,9,5)

# %%
print(nested_tuple)
# Out:
# (4, 5, (5, 6), (5, 5, 8, 9, 8), 6, 9, 5)

# %%
nested_tuple[2]
# Out:
# (5, 6)

# %%
nested_tuple[2:4]
# Out:
# ((5, 6), (5, 5, 8, 9, 8))

# %%
x=(10,)
print(type(x))
# Out:
# <class 'tuple'>

# %%
nested_tuple
# Out:
# (4, 5, (5, 6), (5, 5, 8, 9, 8), 6, 9, 5)

# %%
nested_tuple[::-1]
# Out:
# (5, 9, 6, (5, 5, 8, 9, 8), (5, 6), 5, 4)

# %%
a='Develper'
a[::-1]
# Out:
# 'repleveD'

# %%
a=(1,2)
b=(3,4)
c=a+b

# %%
c
# Out:
# (1, 2, 3, 4)

# %%
type(c)
# Out:
# tuple

# %% [markdown]
# REPEATATION

# %%
a*3
# Out:
# (1, 2, 1, 2, 1, 2)

# %% [markdown]
# MEMBERSHIP

# %%
a=(4,5,8,7,9,10)
print(4 in a)
# Out:
# True

# %%
a=(4,5,8,7,9,10)
print(20 in a)
# Out:
# False

# %% [markdown]
# Tuple Function

# %%
len(a)
# Out:
# 6

# %%
min(a)
# Out:
# 4

# %%
max(a)
# Out:
# 10

# %%
sum(a)
# Out:
# 43

# %%
a=sorted(a)
a
# Out:
# [4, 5, 7, 8, 9, 10]

# %%
a[::-1]
# Out:
# [10, 9, 8, 7, 5, 4]

# %%
a.count(8)
# Out:
# 1

# %%
a.index(10)
# Out:
# 5

# %%
a=(4,5,8,7,9,10)
tuple(sorted(a,reverse=True))
# Out:
# (10, 9, 8, 7, 5, 4)

# %%
a
# Out:
# (4, 5, 8, 7, 9, 10)

# %%
a[2]=10 # immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 a[2]=10 # immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=list(a)

# %%
a[2]=10

# %%
tuple(a)
# Out:
# (4, 5, 10, 7, 9, 10)

# %%
a
# Out:
# [4, 5, 10, 7, 9, 10]

# %% [markdown]
# Packing & Unpacking

# %%
student=("Vishnu",23,'India')

# %%
name,age,contry=student

# %%
name
# Out:
# 'Vishnu'

# %%
age
# Out:
# 23

# %%
contry
# Out:
# 'India'

# %%
student2=name,age,contry

# %%
student2
# Out:
# ('Vishnu', 23, 'India')

# %%
student2=name+age+contry
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 student2=name+age+contry
#
# TypeError: can only concatenate str (not "int") to str

# %%
student=("Vishnu",'23','India')
name,age,country=student

# %%
student3=name,age,country

# %%
student3
# Out:
# ('Vishnu', '23', 'India')

# %%
print('Hello Developer',end=" ")
print("Hello Vishnu")
# Out:
# Hello Developer Hello Vishnu

# %%
student=("Vishnu",23,'India')

# %%
print(student,sep=",")
# Out:
# ('Vishnu', 23, 'India')

# %%
a=10
b=20
c=30
print(a,b,c,sep="\n")
# Out:
# 10
# 20
# 30

# %% [markdown]
# Nested Tuple

# %%
data=(("Ram",1),("Shyam",2),("Rahul",3))

# %%
data
# Out:
# (('Ram', 1), ('Shyam', 2), ('Rahul', 3))

# %%
data[1][0]
# Out:
# 'Shyam'

# %% [markdown]
# Practice Exercises
# Create a tuple with 5 numbers and print its sum & average.
# Access the 3rd element using negative indexing.
# Convert this list into a tuple:
# l = ["a", "b", "c"]
# Create two tuples and join them.
# Count how many times 10 appears in (10, 20, 10, 30, 10).
# Unpack a tuple (‘Vishnu’, 22, ‘Python Developer’) into 3 variables.
# Create a nested tuple and access the inner element.
# Convert tuple (1,2,3) into a list, change 2 → 99, and convert back.
# Reverse a tuple without using slicing.
# Sort tuple (50, 10, 30, 20) in ascending order.
