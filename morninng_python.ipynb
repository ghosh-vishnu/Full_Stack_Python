# %%
# This is my First Programming in python
a=5
b=6
print(a+b)
# Out:
# 11

# %%
"""This is first coding in python
and i am very excited"""
a=5
b=6
print(a+b)
# Out:
# 11

# %%
@12="Python"
# Out:
#   Cell In[9], line 1
#     @12="Python"
#      ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
123="Python"
# Out:
#   Cell In[10], line 1
#     123="Python"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a2="python"

# %%
2s=python
# Out:
#   Cell In[12], line 1
#     2s=python
#     ^
# SyntaxError: invalid decimal literal

# %%
@1name="python"
# Out:
#   Cell In[14], line 1
#     @1name="python"
#      ^
# SyntaxError: invalid decimal literal

# %%
_="python"

# %%
print(_)
# Out:
# python

# %%
_name="python"

# %%
name__=123

# %%
na_me=52

# %%
nam@5="python"
# Out:
#   Cell In[21], line 1
#     nam@5="python"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a="Python"
print(type(a))
# Out:
# <class 'str'>

# %%
a="""Python"""
print(type(a))
# Out:
# <class 'str'>

# %%
a='''Python'''
print(type(a))
# Out:
# <class 'str'>

# %%
print(a)
# Out:
# Python

# %%
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
a=10.5
print(type(a))
# Out:
# <class 'float'>

# %%
a=2j
b=5
print(type(a))
print(a+b)
# Out:
# <class 'complex'>
# (5+2j)

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=[10,25,1,1,20.5,63,"Python","January","Python"]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
print(a[7])
# Out:
# January

# %%
print(a[0:6])
# Out:
# [10, 25, 1, 1, 20.5, 63]

# %%
# tuple
a=(25,36,36,42,52)

# %%
print(a)
# Out:
# (25, 36, 36, 42, 52)

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
print(a[3])
# Out:
# 42

# %%
# Dictionary
a={"a":"Apple","b":"Ball"}
a.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
print(a)
# Out:
# {'a': 'Apple', 'b': 'Ball'}

# %%
print(type(a))
# Out:
# <class 'dict'>

# %%
print(a["b"])
# Out:
# Ball

# %%
# set
a={25,25,25,2,5,5}

# %%
print(a)
# Out:
# {25, 2, 5}

# %%
print(a)
# Out:
# {25, 2, 5}
