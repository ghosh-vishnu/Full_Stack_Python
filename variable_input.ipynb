# %%
print("Hello Developer")
print("Hello Team")
# Out:
# Hello Developer
# Hello Team

# %%
print("Hello Developer",end=' and ')
print("Hello Team")
# Out:
# Hello Developer and Hello Team

# %%
print("Hello Developer","Team",sep=' ')
# Out:
# Hello Developer Team

# %%
a=10  #type---int
b="Gopal"  #---str

# %%
print(b)
# Out:
# Gopal

# %%
c=10.5
d=True

# %%
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# 10 <class 'int'>
# Gopal <class 'str'>
# 10.5 <class 'float'>
# True <class 'bool'>

# %%
a=input("Enter Your Name")
print(a)
type(a)
# Out:
# str

# %%
a=int(input("Enter Your First Number:"))
b=int(input("Enter Your Secound Number"))
c=a+b
print("Your 2 Digit Sum is :",c)
print(type(c))
# Out:
# Your 2 Digit Sum is : 108
# <class 'int'>

# %%
print(a)
# Out:
# 54

# %%
a='58'
print(type(a))
# Out:
# <class 'str'>

# %%
a=int(a)

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(a)
# Out:
# 58

# %%
o="Python"

# %%
print(type(o))
int(o)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 print(type(o))
# ----> 2 int(o)
#
# ValueError: invalid literal for int() with base 10: 'Python'

# %%
u='10.5'

# %%
print(type(u))
print(int(float(u)))
# Out:
# <class 'str'>
# 10

# %%
s=input("Enter Your Name:")
print("Your Name is",s)
# Out:
# Your Name is Vishal

# %% [markdown]
# Data Types In Python
#    >1.  Text Data Type
#                     >---str
#                     >    syntax("" /'')
#                     >    bydefault input()---str
#     >2. Numeric Data
#                     >int  1
#                     >float 1.0
#                     >complex 1i+1j
#     >3. Sequence Data Type
#                     >List   []
#                     >Tuple ()
#                     >range(5)
#     >4. Mapping Data Type
#                     >Dict {:}
#     >5. Set Data Types
#                     >set {}
#                     >frozenset ({})
#     >6.Binary Data Type
#                     >bytes,'memoryview,bytearray
#     >7. bool
#                 >True
#                 >False

# %% [markdown]
# STRING DATATYPE

# %%
a="Hello Developer"
b='apple'
c=int(input("Enter your age :"))

# %%
print(type(a),a)
print(type(b),b)
print(type(c),c)
# Out:
# <class 'str'> Hello Developer
# <class 'str'> apple
# <class 'int'> 56

# %% [markdown]
# Numerical datatype

# %%
a=18
b=1.4
c=True
d=2j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %% [markdown]
# Sequence Data Type
# > 1. List
#         -It is a collection of multiple datatype
#         -it allow to store duplicates value.
#         -List Literal is []
#         -List is mutable datatype
#         -List helps to store multiple value in a single variable
# syntax
#         a=['Apple',"Banana",50,465]

# %%
fruits=["Apple","Banana","Mango","Gobhi"]

# %%
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
list1=["Apple","Banana","Mango","Gobhi",2j,3,5.5,True,True]

# %%
print(list1)
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi', 2j, 3, 5.5, True, True]

# %%
a,b,c=10,15,20

# %%
print(b)
print(a)
print(c)
# Out:
# 15
# 10
# 20

# %%
print(fruits[2])
print(fruits[0:3])
# Out:
# Mango
# ['Apple', 'Banana', 'Mango']

# %%
selected_fruits=fruits[0],fruits[2]

# %%
print(selected_fruits)
# Out:
# ('Apple', 'Mango')

# %%
print(fruits[2])
print(fruits[0:3]+fruits[-2:])
# Out:
# Mango
# ['Apple', 'Banana', 'Mango', 'Mango', 'Gobhi']

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi']

# %%
selected_fruits=selected_fruits[1]

# %%
if "Mango" in fruits:
    print("Yes available")
else:
    print("Not Available")
# Out:
# Yes available

# %%
print(selected_fruits)
# Out:
# Mango

# %%
student=["Mohan","Ravi","Shyam","Gurpreet"]

# %%
print(student)
# Out:
# ['Mohan', 'Ravi', 'Shyam', 'Gurpreet']

# %%
student[1]="Vishal"
student[2]="Ram"

# %%
student
# Out:
# ['Mohan', 'Vishal', 'Ram', 'Gurpreet']

# %%
print(student[1:3])
# Out:
# ['Vishal', 'Ram']

# %%
student[1:3]=["Vikash","Sita"]

# %%
student
# Out:
# ['Mohan', 'Vikash', 'Sita', 'Gurpreet']

# %%
classes=[student[0],student[3]]

# %%
classes=[student[0],student[2]]

# %%
print(classes)
type(classes)
# Out:
# ['Mohan', 'Sita']
# list

# %%
classes[0]='Sawan'

# %%
classes
# Out:
# ['Sawan', 'Sita']

# %%
student
# Out:
# ['Mohan', 'Vikash', 'Sita', 'Gurpreet']

# %%
student[0]='Sawan'
student[3]='Rahul'
print(student)
# Out:
# ['Sawan', 'Vikash', 'Sita', 'Rahul']

# %%
student[2],student[0]="Vishnu","Rahul Kumar ram"

# %%
b=8
a=6
b=a
print(b)
# Out:
# 6

# %%
b=8
a=6
a=b
print(a)
# Out:
# 8

# %%
ram=28
shyam=36
ram=shyam
print(shyam)
# Out:
# 36

# %%
a=36
b=57
a,b=b,a
print(a)
print(b)
# Out:
# 57
# 36

# %%
print(classes+student)
# Out:
# ['Sawan', 'Sita', 'Rahul Kumar ram', 'Vikash', 'Vishnu', 'Rahul']

# %%
student
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Vishnu', 'Rahul']

# %%
student.insert(3,"VINOD KUMAR SINGH")

# %%
student
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Vishnu', 'VINOD KUMAR SINGH', 'Rahul']

# %%
print(type(updated_student))
# Out:
# <class 'NoneType'>

# %%
print(updated_student)
# Out:
# None

# %%
updated_CLASS=student.copy()

# %%
print(updated_CLASS)
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Vishnu', 'VINOD KUMAR SINGH', 'Rahul']

# %%
updated_CLASS.insert(2,"Radha")

# %%
print(updated_CLASS)
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Radha', 'Vishnu', 'VINOD KUMAR SINGH', 'Rahul']

# %%
student
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Vishnu', 'VINOD KUMAR SINGH', 'Rahul']

# %%
student=updated_CLASS

# %%
print(student)
# Out:
# ['Rahul Kumar ram', 'Vikash', 'Vishnu', 'VINOD KUMAR SINGH', 'Rahul']

# %%
updated_student.append("Sawan")

# %%
updated_student
# Out:
# ['Vishnu', 'Vikash', 'Radha', 'Sita', 'Rahul Kumar ram', 'Sawan']

# %%
student
# Out:
# ['Vishnu', 'Vikash', 'Sita', 'Rahul Kumar ram']

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Mango',
#  'Gobhi',
#  'Brinjal',
#  'Chili',
#  'Potato',
#  'Tomato',
#  'Brinjal',
#  'Chili',
#  'Potato',
#  'Tomato',
#  'Brinjal',
#  'Chili',
#  'Potato',
#  'Tomato']

# %%
vegetable=['Brinjal',"Chili","Potato","Tomato"]
fruit=['Apple', 'Banana', 'Mango', 'Gobhi']

# %%
fruit.extend(vegetable)

# %%
print(fruit)
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi', 'Brinjal', 'Chili', 'Potato', 'Tomato']

# %%
print(vegetable)
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato']

# %%
print(fruit+vegetable)
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi', 'Brinjal', 'Chili', 'Potato', 'Tomato']

# %%
print(fruit)
print(vegetable)
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi']
# ['Brinjal', 'Chili', 'Potato', 'Tomato']

# %%
vegetable=['Brinjal',"Chili","Potato","Tomato"]
price=(20,45,60,25,70)
weight={1.5,2,3,5.5}
dic={"Vishal":5,"Vinod":10}
vegetable.extend(dic)
print(type(price))
# Out:
# <class 'tuple'>

# %%
print(vegetable)
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato', 'Vishal', 'Vinod']

# %%
vegetable.pop(4)
# Out:
# 'Vishal'

# %%
vegetable
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato', 'Vinod']

# %%
vegetable.pop(4:5)
# Out:
#   Cell In[236], line 1
#     vegetable.pop(4:5)
#                    ^
# SyntaxError: invalid syntax

# %%
vegetable.remove("Vishal")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 vegetable.remove("Vishal")
#
# ValueError: list.remove(x): x not in list

# %%
vegetable
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato', 'Vinod']

# %%
vegetable.remove("Vinod")

# %%
print(vegetable)
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato']

# %%
vegetable.pop()
# Out:
# 'Tomato'

# %%
vegetable.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[242], line 1
# ----> 1 vegetable.remove()
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
del vegetable[0:]

# %%
vegetable
# Out:
# []

# %%
a=[]
print(type(a))
# Out:
# <class 'list'>

# %%
print(a)
# Out:
# []

# %%
vegetable=['Brinjal',"Chili","Potato","Tomato"]
price=(20,45,60,25,70)
weight={1.5,2,3,5.5}
dic={"Vishal":5,"Vinod":10}
vegetable.extend(dic)
print(type(price))
# Out:
# <class 'tuple'>

# %%
vegetable
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato', 'Vishal', 'Vinod']

# %%
vegetable.clear()

# %%
print(vegetable)
# Out:
# ['Brinjal', 'Chili', 'Potato', 'Tomato', 'Vishal', 'Vinod']

# %%
for i in vegetable:
    print(i)
# Out:
# Brinjal
# Chili
# Potato
# Tomato
# Vishal
# Vinod

# %%
for i in vegetable:
    print(i,len(i))
# Out:
# Brinjal 7
# Chili 5
# Potato 6
# Tomato 6
# Vishal 6
# Vinod 5

# %%
[print (i,len(i)) for i in vegetable]# LIST COMPREHENSSION
# Out:
# Brinjal 7
# Chili 5
# Potato 6
# Tomato 6
# Vishal 6
# Vinod 5
# [None, None, None, None, None, None]

# %%
New_fruit=[]
for i in fruit:
    if 'a' in i:
        New_fruit.append(i)
    elif 'A' in i:
        New_fruit.append(i)
print(New_fruit)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
fruit
# Out:
# ['Apple', 'Banana', 'Mango', 'Gobhi']

# %%
New_fruit=[i for i in fruit if 'a' in i elif 'A' in i]
# Out:
#   Cell In[287], line 1
#     New_fruit=[i for i in fruit if 'a' in i elif 'A' in i]
#                                             ^
# SyntaxError: invalid syntax

# %%
New_fruit
# Out:
# ['Banana', 'Mango']

# %%
New_fruit=[i for i in fruit if 'a' in i or 'A' in i]

# %%
New_fruit
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
New_fruit1=[i for i in fruit if 'a' in i.lower()]

# %%
New_fruit1
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
q="Rahul"
q
# Out:
# 'Rahul'

# %%
q.lower()
# Out:
# 'rahul'

# %%
q.upper()
# Out:
# 'RAHUL'

# %%
New_fruit=[]
for i in fruit:
    if 'a' in i:
        New_fruit.append(i)
    elif 'A' in i:
        New_fruit.append(i)
    print(i)
print(New_fruit)
# Out:
# Apple
# Banana
# Mango
# Gobhi
# ['Apple', 'Banana', 'Mango']

# %%
New_fruit1=[i.lower() for i in fruit if 'a' in i.lower()]
print(i)
# Out:
# Gobhi

# %%
New_fruit1
# Out:
# ['apple', 'banana', 'mango']

# %%
a=list((52,45,28,45))
print(type(a))
# Out:
# <class 'list'>

# %%
print(a)
# Out:
# [52, 45, 28, 45]

# %%
# list()---list constructor

# %%
list1=['A','B','C','D']
list2=[1,2,3,4,5]
list3=list1+list2

# %%
list3
# Out:
# ['A', 'B', 'C', 'D', 1, 2, 3, 4, 5]

# %%
list1=['A','B','C','D','E']
list2=[1,2,3,4,5,'D']
for i in list2:
    list1.append(i)
print(list1)
# Out:
# ['A', 'B', 'C', 'D', 'E', 1, 2, 3, 4, 5, 'D']

# %%
list1.extend(list2)

# %%
print(list2)
list1
# Out:
# [1, 2, 3, 4, 5, 'D']
# ['A', 'B', 'C', 'D', 'E', 1, 2, 3, 4, 5, 'D', 1, 2, 3, 4, 5, 'D']

# %%
list1
list1.count('D')
# Out:
# 3

# %%
list1.index(5)
# Out:
# 9

# %%
list1.reverse()

# %%
list1
# Out:
# ['D', 5, 4, 3, 2, 1, 'D', 5, 4, 3, 2, 1, 'E', 'D', 'C', 'B', 'A']

# %%
student.reverse()

# %%
student
# Out:
# ['Rahul', 'VINOD KUMAR SINGH', 'Vishnu', 'Vikash', 'Rahul Kumar ram']

# %%
fruit=() # emplty tuple

# %%
type(fruit)
# Out:
# tuple

# %%
fruit=("Apple","Grapes","Banana",4,5,6)

# %%
print(fruit)
# Out:
# ('Apple', 'Grapes', 'Banana', 4, 5, 6)

# %% [markdown]
# NESTED TUPLE

# %%
nested_tuple=(4,5,(5,6),(5,5,8,9,8),6,9,5)

# %%
print(nested_tuple)
# Out:
# (4, 5, (5, 6), (5, 5, 8, 9, 8), 6, 9, 5)

# %%
# Out:
# (5, 6)

# %%
# Out:
# ((5, 6), (5, 5, 8, 9, 8))

# %%
# Out:
# <class 'tuple'>

# %%
# Out:
# (4, 5, (5, 6), (5, 5, 8, 9, 8), 6, 9, 5)

# %%
# Out:
# (5, 9, 6, (5, 5, 8, 9, 8), (5, 6), 5, 4)

# %%
# Out:
# 'repleveD'

# %%
# Out:
# (1, 2, 3, 4)

# %%
# Out:
# tuple

# %%
# Out:
# (1, 2, 1, 2, 1, 2)
