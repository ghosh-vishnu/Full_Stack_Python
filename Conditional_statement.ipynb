# %%
age=int(input("Enter Your Age:"))
if age>18:
    print("Yes, You Are Eligible for Voting")

# %%
age=int(input("Enter Your Age:"))
if age>18:
    print("Yes, You Are Eligible for Voting")
else:
    print("Not Eligible")
# Out:
# Not Eligible

# %%
marks=int(input("Enter Your Marks"))
if marks>90:
    print("Grade A")
elif marks>75:
    print("Grade B")
elif marks>65:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
age=int(input("Enter Your Age"))
citizen=input("Enter Your Citizen")
if age>18:
    if citizen=="Dubai":
        print("Your Are Eligible For Voting")
    else:
        print("You Must be Citizen")
else:
    print("Your Are Underage")
# Out:
# You Must be Citizen

# %%
# Short Hand 
a=25
b=20
print("A IS GREATER" if a>b else print("B is Greater"))
# Out:
# A IS GREATER

# %%
Try yourself

Q1. Check if a number is positive, negative or zero
Q2. Check if number is even or odd
Q3. Accept marks and print Grade
Q4. Take input age and check eligibility for driving license (>= 18)
Q5. Accept username & password and check login success

# %%
print("=================WELCOME TO SBI ATM==================")
set_pin=int(input("Enter Your PIN:"))
balance=10000
password=set_pin
login=int(input("Enter Your PIN"))
if password==login:
    withdraw_amount=int(input("Enter Your Amount:"))
    if withdraw_amount<=10000:
        if withdraw_amount % 100==0:
            print("Withdraw SuccessFully")
            remain=balance-withdraw_amount
            print("Total Remaining Balance:",remain)
        else:
            print("Please Enter Multiplese of 100")
    else:
        print("Insufficient Amount")
else:
    print("Incorrect Password")
print("Thank You")
# Out:
# =================WELCOME TO SBI ATM==================
# Incorrect Password
# Thank You

# %%
print(password)
# Out:
# 8585

# %%
print("=================WELCOME TO SBI ATM==================")
set_pin=int(input("Enter Your PIN:"))
balance=10000
password=set_pin
login=int(input("Enter Your PIN"))
if password==login:
    print("\n==============Login Successfully===============\n")
    
    print("========ATM MENU==========")
    print("1.Check Balance")
    print("2.Withdraw Money")
    print("3.Deposit Money")
    print("4.Pin Change")
    
    choose=int(input("Enter Your Choise"))
    if choose==1:
        print("Your Balance is:",balance)
    elif choose==2:
        withdraw_amount=int(input("Enter Your Amount:"))
        if withdraw_amount<=10000 and withdraw_amount>=1:
            if withdraw_amount % 100==0:
                print("Withdraw SuccessFully")
                balance-=withdraw_amount
                print("-------------------------")
                print("Total Withdraw Amount:",withdraw_amount)
                print("Total Remaining Amount:",balance)
            else:
                print("Please Enter Multiplese of 100")
        else:
            print("Incoorect Amount")
            print("Insufficient Amount")
    elif choose==3:
        deposit=int(input("Enter Your Deposit Amount:"))
        if deposit>=0:
            print("Deposit Successfully")
            balance+=deposit
        else:
            print("Please Enter Valid Amount")
    elif choose==4:
        update_pin=int(input("Enter Your NEW PIN"))
        password=update_pin
else:
    print("Incorrect Password")

print("Thank You")
# Out:
# =================WELCOME TO SBI ATM==================
#
# ==============Login Successfully===============
#
# ========ATM MENU==========
# 1.Check Balance
# 2.Withdraw Money
# 3.Deposit Money
# 4.Pin Change
# Incoorect Amount
# Insufficient Amount
# Thank You

# %%
print(password)
print(balance)
# Out:
# 5252
# 12000
