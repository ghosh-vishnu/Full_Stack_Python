# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
marks=[30,40,48,68,50]

# %%
marks
# Out:
# [30, 40, 48, 68, 50]

# %%
import pandas as pd 
marks=[30,40,48,68,50]
s=pd.Series(marks)
print(s)
# Out:
# 0    30
# 1    40
# 2    48
# 3    68
# 4    50
# dtype: int64

# %%
# Dataframe creation:
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'Age': [25, 30, 35,40, 28, 33, 29, 31, 27, 26],
    'marks': [85, 90, 95,90, 88, 92, 87, 91, 89, 93],
    "city": ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose']
}

# %%
data.keys()
# Out:
# dict_keys(['Name', 'Age', 'marks', 'city'])

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age  marks          city
# 0    Alice   25     85      New York
# 1      Bob   30     90   Los Angeles
# 2  Charlie   35     95       Chicago
# 3    David   40     90       Houston
# 4      Eva   28     88       Phoenix
# 5    Frank   33     92  Philadelphia
# 6    Grace   29     87   San Antonio
# 7   Hannah   31     91     San Diego
# 8      Ian   27     89        Dallas
# 9     Jack   26     93      San Jose

# %%
df.head()
# Out:
#       Name  Age  marks         city
# 0    Alice   25     85     New York
# 1      Bob   30     90  Los Angeles
# 2  Charlie   35     95      Chicago
# 3    David   40     90      Houston
# 4      Eva   28     88      Phoenix

# %%
df.tail()
# Out:
#      Name  Age  marks          city
# 5   Frank   33     92  Philadelphia
# 6   Grace   29     87   San Antonio
# 7  Hannah   31     91     San Diego
# 8     Ian   27     89        Dallas
# 9    Jack   26     93      San Jose

# %%
df.shape
# Out:
# (10, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'marks', 'city'], dtype='object')

# %%
df[['Age','city','Name']]
# Out:
#    Age          city     Name
# 0   25      New York    Alice
# 1   30   Los Angeles      Bob
# 2   35       Chicago  Charlie
# 3   40       Houston    David
# 4   28       Phoenix      Eva
# 5   33  Philadelphia    Frank
# 6   29   San Antonio    Grace
# 7   31     San Diego   Hannah
# 8   27        Dallas      Ian
# 9   26      San Jose     Jack

# %%
df[df['Age']<=30]
# Out:
#     Name  Age  marks         city
# 0  Alice   25     85     New York
# 1    Bob   30     90  Los Angeles
# 4    Eva   28     88      Phoenix
# 6  Grace   29     87  San Antonio
# 8    Ian   27     89       Dallas
# 9   Jack   26     93     San Jose

# %%
df.loc[0:6, "Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# 6      Grace
# Name: Name, dtype: object

# %%
df['result']=['pass' if marks>=90 else 'fail' for marks in df['marks']]

# %%
df['feedback']=df['marks'].apply(lambda x: 'excellent' if x>=90 else 'good' if x>=80 else 'average')

# %%
df
# Out:
#       Name  Age  marks          city result   feedback
# 0    Alice   25     85      New York   fail       good
# 1      Bob   30     90   Los Angeles   pass  excellent
# 2  Charlie   35     95       Chicago   pass  excellent
# 3    David   40     90       Houston   pass  excellent
# 4      Eva   28     88       Phoenix   fail       good
# 5    Frank   33     92  Philadelphia   pass  excellent
# 6    Grace   29     87   San Antonio   fail       good
# 7   Hannah   31     91     San Diego   pass  excellent
# 8      Ian   27     89        Dallas   fail       good
# 9     Jack   26     93      San Jose   pass  excellent

# %%
df['marks'].apply(lambda x: 'excellent' if x>=90 else 'good' if x>=80 else 'average')
# Out:
# 0         good
# 1    excellent
# 2    excellent
# 3    excellent
# 4         good
# 5    excellent
# 6         good
# 7    excellent
# 8         good
# 9    excellent
# Name: marks, dtype: object

# %%
def check(x):
    if x>=90:
        return 'excellent'
    elif x>=80:
        return 'good'
    else:
        return 'average'
check(78)
# Out:
# 'average'

# %%
b=lambda x:"excellent" if x>=90 else 'good' if x>=80 else 'average'

# %%
b(54)
# Out:
# 'average'

# %%
def check(x):
    if x>=90:
        return 'excellent'
    elif x>=80:
        return 'good'
    else:
        return 'average'
check(78)
# Out:
# 'average'

# %%
marks_list=[20,40,48,68,20,78,88,90,95,100]
result=[]
for m in marks_list:
    if m>=90:
        result.append('excellent')
    elif m>=80:
        result.append('good')
    elif m>=30:
        result.append('average')
    else:
        result.append('fail')
print(result)
# Out:
# ['fail', 'average', 'average', 'average', 'fail', 'average', 'good', 'excellent', 'excellent', 'excellent']

# %%
df['Grade']=''

# %%
def grade(x):
    if x>=95:
        return 'A'
    elif x>=85:
        return 'abc'
    elif x>=75:
        return 'C'
    elif x>=65:
        return 'D'
    else:
        return 'F'
df['Grade']=df['marks'].apply(grade)

# %%
df
# Out:
#       Name  Age  marks          city result   feedback Grade
# 0    Alice   25     85      New York   fail       good   abc
# 1      Bob   30     90   Los Angeles   pass  excellent   abc
# 2  Charlie   35     95       Chicago   pass  excellent     A
# 3    David   40     90       Houston   pass  excellent   abc
# 4      Eva   28     88       Phoenix   fail       good   abc
# 5    Frank   33     92  Philadelphia   pass  excellent   abc
# 6    Grace   29     87   San Antonio   fail       good   abc
# 7   Hannah   31     91     San Diego   pass  excellent   abc
# 8      Ian   27     89        Dallas   fail       good   abc
# 9     Jack   26     93      San Jose   pass  excellent   abc

# %%
df['Grade']=df['marks'].apply(grade)

# %%
df
# Out:
#       Name  Age  marks          city result   feedback Grade
# 0    Alice   25     85      New York   fail       good   abc
# 1      Bob   30     90   Los Angeles   pass  excellent   abc
# 2  Charlie   35     95       Chicago   pass  excellent     A
# 3    David   40     90       Houston   pass  excellent   abc
# 4      Eva   28     88       Phoenix   fail       good   abc
# 5    Frank   33     92  Philadelphia   pass  excellent   abc
# 6    Grace   29     87   San Antonio   fail       good   abc
# 7   Hannah   31     91     San Diego   pass  excellent   abc
# 8      Ian   27     89        Dallas   fail       good   abc
# 9     Jack   26     93      San Jose   pass  excellent   abc

# %%
# HOW TO READ CSV FILE IN PANDAS
import pandas as pd

# %%
df1=pd.read_csv(r'C:\Users\Vishnu\Downloads\DATA.csv')

# %%
df1.rename(columns={'name':'Student'}, inplace=True)

# %%
df1.value_counts()
# Out:
# Student  roll  address  marks
# amit     1     noida    65       1
# binod    4     delhi    75       1
# sunil    5     bihar    95       1
# Name: count, dtype: int64

# %%
df1
# Out:
#     name  roll address  marks
# 0   amit     1   noida     65
# 1  binod     4   delhi     75
# 2  sunil     5   bihar     95

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  3 non-null      object
#  1   roll     3 non-null      int64
#  2   address  3 non-null      object
#  3   marks    3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df1.isnull().value_counts()
# Out:
# Student  roll   address  marks
# False    False  False    False    3
# Name: count, dtype: int64

# %%
df=pd.read_excel(r'D:\Ved_Official\Project_data Analytics\weather.xlsx')

# %%
df
# Out:
#     date  temperature  windspeed  event  ABC  Year
# 0  44562         32.0        6.0   Rain   17  2022
# 1  44563          NaN        9.0  Sunny   14  2022
# 2  44564         28.0        NaN   Snow   10  2022
# 3  44565          NaN        7.0    NaN   12  2022
# 4  44566         32.0        NaN   Rain   17  2022
# 5  44567          NaN        NaN  Sunny   10  2022
# 6  44568          NaN        NaN    NaN   15  2022
# 7  44569         34.0        8.0  Cloud   11  2022
# 8  44570         40.0       12.0  Sunny   19  2022
# 9  44571         30.0       10.0  Sunny   19  2022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         10 non-null     int64
#  1   temperature  6 non-null      float64
#  2   windspeed    6 non-null      float64
#  3   event        8 non-null      object
#  4   ABC          10 non-null     int64
#  5   Year         10 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 612.0+ bytes

# %%
df.isnull()
# Out:
#     date  temperature  windspeed  event    ABC   Year
# 0  False        False      False  False  False  False
# 1  False         True      False  False  False  False
# 2  False        False       True  False  False  False
# 3  False         True      False   True  False  False
# 4  False        False       True  False  False  False
# 5  False         True       True  False  False  False
# 6  False         True       True   True  False  False
# 7  False        False      False  False  False  False
# 8  False        False      False  False  False  False
# 9  False        False      False  False  False  False

# %%
df=df.drop(columns='ABC',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 df=df.drop(columns='ABC',axis=0)
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
df.dropna()
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
a=df['temperature'].mean()

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563          NaN        9.0  Sunny  2022
# 2  44564         28.0        NaN   Snow  2022
# 3  44565          NaN        7.0    NaN  2022
# 4  44566         32.0        NaN   Rain  2022
# 5  44567          NaN        NaN  Sunny  2022
# 6  44568          NaN        NaN    NaN  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
df.fillna(a)
# Out:
#     date  temperature  windspeed      event  Year
# 0  44562    32.000000   6.000000       Rain  2022
# 1  44563    32.666667   9.000000      Sunny  2022
# 2  44564    28.000000  32.666667       Snow  2022
# 3  44565    32.666667   7.000000  32.666667  2022
# 4  44566    32.000000  32.666667       Rain  2022
# 5  44567    32.666667  32.666667      Sunny  2022
# 6  44568    32.666667  32.666667  32.666667  2022
# 7  44569    34.000000   8.000000      Cloud  2022
# 8  44570    40.000000  12.000000      Sunny  2022
# 9  44571    30.000000  10.000000      Sunny  2022

# %%
df.ffill()
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563         32.0        9.0  Sunny  2022
# 2  44564         28.0        9.0   Snow  2022
# 3  44565         28.0        7.0   Snow  2022
# 4  44566         32.0        7.0   Rain  2022
# 5  44567         32.0        7.0  Sunny  2022
# 6  44568         32.0        7.0  Sunny  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
df.bfill()
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563         28.0        9.0  Sunny  2022
# 2  44564         28.0        7.0   Snow  2022
# 3  44565         32.0        7.0   Rain  2022
# 4  44566         32.0        8.0   Rain  2022
# 5  44567         34.0        8.0  Sunny  2022
# 6  44568         34.0        8.0  Cloud  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563          NaN        9.0  Sunny  2022
# 2  44564         28.0        NaN   Snow  2022
# 3  44565          NaN        7.0    NaN  2022
# 4  44566         32.0        NaN   Rain  2022
# 5  44567          NaN        NaN  Sunny  2022
# 6  44568          NaN        NaN    NaN  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
df['temperature'].ffill(inplace=True)

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563         32.0        9.0  Sunny  2022
# 2  44564         28.0        NaN   Snow  2022
# 3  44565         28.0        7.0    NaN  2022
# 4  44566         32.0        NaN   Rain  2022
# 5  44567         32.0        NaN  Sunny  2022
# 6  44568         32.0        NaN    NaN  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
# df.temperature.index=[1]
df['temperature'][2]=99
# Out:
# C:\Users\Vishnu\AppData\Local\Temp\ipykernel_4516\108131297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temperature'][2]=99

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0   Rain  2022
# 1  44563         32.0        9.0  Sunny  2022
# 2  44564         99.0        NaN   Snow  2022
# 3  44565         28.0        7.0    NaN  2022
# 4  44566         32.0        NaN   Rain  2022
# 5  44567         32.0        NaN  Sunny  2022
# 6  44568         32.0        NaN    NaN  2022
# 7  44569         34.0        8.0  Cloud  2022
# 8  44570         40.0       12.0  Sunny  2022
# 9  44571         30.0       10.0  Sunny  2022

# %%
df['temperature'].mean()
# Out:
# np.float64(39.1)

# %%
df['temperature'].median()
# Out:
# np.float64(32.0)

# %%
df['temperature'].mode()
# Out:
# 0    32.0
# Name: temperature, dtype: float64

# %%
O

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0      0  2022
# 1  44563         32.0        9.0      0  2022
# 2  44564         99.0        NaN      0  2022
# 3  44565         28.0        7.0      0  2022
# 4  44566         32.0        NaN      0  2022
# 5  44567         32.0        NaN      0  2022
# 6  44568         32.0        NaN      0  2022
# 7  44569         34.0        8.0      0  2022
# 8  44570         40.0       12.0      0  2022
# 9  44571         30.0       10.0      0  2022

# %%
df['event'] = df['event'].apply(lambda x: 1 if x == "Rain" else 2 if x == "Cloudy" else 0)

# %%
df.value_counts()
# Out:
# date   temperature  windspeed  event  Year
# 44562  32.0         6.0        0      2022    1
# 44563  32.0         9.0        0      2022    1
# 44565  28.0         7.0        0      2022    1
# 44569  34.0         8.0        0      2022    1
# 44570  40.0         12.0       0      2022    1
# 44571  30.0         10.0       0      2022    1
# Name: count, dtype: int64

# %%
df['event'].value_counts()
# Out:
# event
# 0    10
# Name: count, dtype: int64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df['event'].value_counts().isnull(True)
#
# TypeError: Series.isnull() takes 1 positional argument but 2 were given

# %%
df
# Out:
#     date  temperature  windspeed  event  Year
# 0  44562         32.0        6.0      0  2022
# 1  44563         32.0        9.0      0  2022
# 2  44564         99.0        NaN      0  2022
# 3  44565         28.0        7.0      0  2022
# 4  44566         32.0        NaN      0  2022
# 5  44567         32.0        NaN      0  2022
# 6  44568         32.0        NaN      0  2022
# 7  44569         34.0        8.0      0  2022
# 8  44570         40.0       12.0      0  2022
# 9  44571         30.0       10.0      0  2022

# %%
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df
# Out:
#                            date  temperature  windspeed  event  Year
# 0 1970-01-01 00:00:00.000044562         32.0        6.0      0  2022
# 1 1970-01-01 00:00:00.000044563         32.0        9.0      0  2022
# 2 1970-01-01 00:00:00.000044564         99.0        NaN      0  2022
# 3 1970-01-01 00:00:00.000044565         28.0        7.0      0  2022
# 4 1970-01-01 00:00:00.000044566         32.0        NaN      0  2022
# 5 1970-01-01 00:00:00.000044567         32.0        NaN      0  2022
# 6 1970-01-01 00:00:00.000044568         32.0        NaN      0  2022
# 7 1970-01-01 00:00:00.000044569         34.0        8.0      0  2022
# 8 1970-01-01 00:00:00.000044570         40.0       12.0      0  2022
# 9 1970-01-01 00:00:00.000044571         30.0       10.0      0  2022

# %%
df=pd.read_excel(r'D:\Ved_Official\Project_data Analytics\weather.xlsx')

# %%
df
# Out:
#         date  temperature  windspeed  event  ABC  Year
# 0 2022-01-01         32.0        6.0   Rain   17  2022
# 1 2022-01-02          NaN        9.0  Sunny   14  2022
# 2 2022-01-03         28.0        NaN   Snow   20  2022
# 3 2022-01-04          NaN        7.0    NaN   20  2022
# 4 2022-01-05         32.0        NaN   Rain   13  2022
# 5 2022-01-06          NaN        NaN  Sunny   12  2022
# 6 2022-01-07          NaN        NaN    NaN   12  2022
# 7 2022-01-08         34.0        8.0  Cloud   15  2022
# 8 2022-01-09         40.0       12.0  Sunny   19  2022
# 9 2022-01-10         30.0       10.0  Sunny   12  2022

# %%
a=pd.to_datetime(df['date'],format='dd/mm/yyyy')
print(a)
# Out:
# 0   2022-01-01
# 1   2022-01-02
# 2   2022-01-03
# 3   2022-01-04
# 4   2022-01-05
# 5   2022-01-06
# 6   2022-01-07
# 7   2022-01-08
# 8   2022-01-09
# 9   2022-01-10
# Name: date, dtype: datetime64[ns]

# %%
a=pd.to_datetime(df['date'],format='YY-MM-DD')

# %%
df.duplicated().value_counts()
# Out:
# False    10
# Name: count, dtype: int64

# %%
df.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of     date  temperature  windspeed  event    ABC   Year
# 0  False        False      False  False  False  False
# 1  False         True      False  False  False  False
# 2  False        False       True  False  False  False
# 3  False         True      False   True  False  False
# 4  False        False       True  False  False  False
# 5  False         True       True  False  False  False
# 6  False         True       True   True  False  False
# 7  False        False      False  False  False  False
# 8  False        False      False  False  False  False
# 9  False        False      False  False  False  False>

# %%
df.isnull().value_counts()
# Out:
# date   temperature  windspeed  event  ABC    Year
# False  False        False      False  False  False    4
#                     True       False  False  False    2
#        True         False      False  False  False    1
#                                True   False  False    1
#                     True       False  False  False    1
#                                True   False  False    1
# Name: count, dtype: int64

# %%
df
# Out:
#         date  temperature  windspeed  event  ABC  Year
# 0 2022-01-01         32.0        6.0   Rain   17  2022
# 1 2022-01-02          NaN        9.0  Sunny   14  2022
# 2 2022-01-03         28.0        NaN   Snow   20  2022
# 3 2022-01-04          NaN        7.0    NaN   20  2022
# 4 2022-01-05         32.0        NaN   Rain   13  2022
# 5 2022-01-06          NaN        NaN  Sunny   12  2022
# 6 2022-01-07          NaN        NaN    NaN   12  2022
# 7 2022-01-08         34.0        8.0  Cloud   15  2022
# 8 2022-01-09         40.0       12.0  Sunny   19  2022
# 9 2022-01-10         30.0       10.0  Sunny   12  2022

# %%
df.dupicated()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4516\121854467.py in ?()
# ----> 1 df.dupicated()
#
# c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dupicated'

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event  ABC  Year
# 0 2022-01-01         32.0        6.0   Rain   17  2022
# 1 2022-01-02          NaN        9.0  Sunny   14  2022
# 2 2022-01-03         28.0        NaN   Snow   20  2022
# 3 2022-01-04          NaN        7.0    NaN   20  2022
# 4 2022-01-05         32.0        NaN   Rain   13  2022
# 5 2022-01-06          NaN        NaN  Sunny   12  2022
# 6 2022-01-07          NaN        NaN    NaN   12  2022
# 7 2022-01-08         34.0        8.0  Cloud   15  2022
# 8 2022-01-09         40.0       12.0  Sunny   19  2022
# 9 2022-01-10         30.0       10.0  Sunny   12  2022

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='date', y='temperature', kind='line')
# Out:
# <Axes: xlabel='date'>

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='event', y=df['windspeed'],kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[257], line 1
# ----> 1 df.plot(x='event', y=df['windspeed'],kind='bar')
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_core.py:1016, in PlotAccessor.__call__(self, *args, **kwargs)
#    1013             pass
#    1015 # don't overwrite
# -> 1016 data = data[y].copy()
#    1018 if isinstance(data, ABCSeries):
#    1019     label_name = label_kw or y
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df
# Out:
#         date  temperature  windspeed  event  ABC  Year
# 0 2022-01-01         32.0        6.0   Rain   17  2022
# 1 2022-01-02          NaN        9.0  Sunny   14  2022
# 2 2022-01-03         28.0        NaN   Snow   20  2022
# 3 2022-01-04          NaN        7.0    NaN   20  2022
# 4 2022-01-05         32.0        NaN   Rain   13  2022
# 5 2022-01-06          NaN        NaN  Sunny   12  2022
# 6 2022-01-07          NaN        NaN    NaN   12  2022
# 7 2022-01-08         34.0        8.0  Cloud   15  2022
# 8 2022-01-09         40.0       12.0  Sunny   19  2022
# 9 2022-01-10         30.0       10.0  Sunny   12  2022
