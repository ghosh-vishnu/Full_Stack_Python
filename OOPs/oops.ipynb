# %%
    --Top LEVEL Programming Language
    -- POP/FUNCTIONAL PROGRAMMING LANGUGAE
       OOPS
         class
         object
         CONSTRUCTOR
         INHERITANCE
         ENCAPSULATION
         POLIMORPHISM
         ABSTRACTION
# Out:
#   Cell In[76], line 1
#     --Top LEVEL Programming Language
#           ^
# SyntaxError: invalid syntax

# %%
a=2
b=5
c=(a+b)
print(c)
# Out:
# 7

# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %%
def add(a,b):
    return a+b
a=add(5,8)
b=add(8,78)
a,b
# Out:
# (13, 86)

# %%
# lambda :print("I am Vishnu")


a=lambda a,b: a+b
a(5,5)
# Out:
# 10

# %%
def name():
    return "Hello"
    # print("helo")
print(name())
# name()
# Out:
# Hello

# %%
x=lambda :print("Hello")
x()
# Out:
# Hello

# %%
y=lambda :print("Hello")

# %%
y()
# Out:
# Hello

# %%
def jod(a,b):
    print(a+b)
    # return a+b
a=jod(5,60)
print(a)
# Out:
# 65
# None

# %%
a=5
b=60
print(a+b)
# Out:
# 65

# %%
print()

# %%
a=None
print(a)
# Out:
# None

# %%
def xyz(a,b):
    pass
def multiplication(a,b):
    return a*b
print(xyz(1,3))
print(multiplication(2,4))
# Out:
# None
# 8

# %%
def greet():
    name="Amit"
    marks=54
    return f"Hello {name} your marks is {marks}"
print(greet())
print(greet())
# Out:
# Hello Amit your marks is 54
# Hello Amit your marks is 54

# %%
class student():
    name="amit"
    marks=56
a=student()
print(a.name)
print(a.marks)
# Out:
# amit
# 56

# %%
b=10
v=52
c=b+v
print(c)
print(c)
# Out:
# 62
# 62

# %%
class Animal:
    def sound(self):
        cow='mow'
        cat="meou"
x=Animal()
x.sound()

# %%
voice={'cow':"Mow",'cat':"Meuw"}

# %%
voice[]
