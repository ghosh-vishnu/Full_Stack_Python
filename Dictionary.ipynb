# %% [markdown]
# Dictionary

# %%
1> A dictionary is collecgtion which is ordered,changeble(mutable) data types
2 > Dictionary are used to store data in the form keys and Values pair.
3> Dictionary support multiple datatypes for storeing data.
4> Dictionary is not supported duplicates values.
5> Dicgtionary are written in Curly Brackets--{:} ,seprated by : , and have keys and values

# %%
mydict={"Name":"Rahul","Age":24,"Class":"B.Tech"}

# %%
mydict['Name']
# Out:
# 'Rahul'

# %%
print(mydict)
# Out:
# {'Name': 'Rahul', 'Age': 24, 'Class': 'B.Tech'}

# %%
store_age=mydict.get('Age')

# %%
print(store_age)
# Out:
# 24

# %%
a=mydict['Class']

# %%
a
# Out:
# 'B.Tech'

# %%
b=mydict.values()

# %%
b
# Out:
# dict_values(['Rahul', 24, 'B.Tech'])

# %%
b=mydict.keys()

# %%
b
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
company={'Car_Name':"BMW","Model":'X8','Year':2025,'Color':'Black'}

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8', 'Year': 2025, 'Color': 'Black'}

# %%
company['Color']="White"

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8', 'Year': 2025, 'Color': 'White'}

# %%
company={'Car_Name':["BMW",'Alto'],"Model":['X8',800],'Year':[2025,2010],'Color':['Black','Red']}

# %%
company
# Out:
# {'Car_Name': ['BMW', 'Alto'],
#  'Model': ['X8', 800],
#  'Year': [2025, 2010],
#  'Color': ['Black', 'Red']}

# %%
company['Color']=['White','Blue']

# %%
company
# Out:
# {'Car_Name': ['BMW', 'Alto'],
#  'Model': ['X8', 800],
#  'Year': [2025, 2010],
#  'Color': ['White', 'Blue']}

# %%
company['Color']=['White','Blue']

# %%
company[3]['Color']="Red"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 company[3]['Color']="Red"
#
# KeyError: 3

# %%
company
# Out:
# {'Car_Name': ['BMW', 'Alto'],
#  'Model': ['X8', 800],
#  'Year': [2025, 2010],
#  'Color': ['White', 'Blue']}

# %%
car_list=[{'car-name':"BMW",'model':'x8','Year':2025,'Color':'White'},
          {'car-name':"Auto",'model':800,'Year':2010,'Color':'White'}]

# %%
print(type(car_list))
# Out:
# <class 'list'>

# %%
car_list[1]['Color']='Black'

# %%
car_list
# Out:
# [{'car-name': 'BMW', 'model': 'x8', 'Year': 2025, 'Color': 'White'},
#  {'car-name': 'Auto', 'model': 800, 'Year': 2010, 'Color': 'Black'}]

# %%
company={'Car_Name':["BMW",'Alto'],"Model":['X8',800],'Year':[2025,2010],'Color':['Black','Red']}

# %%
company={'Car_Name':["BMW",'Alto'],"Model":['X8',800],'Year':[2025,2010],'Color':['Black','Red']}
car_index=0
print(f'Car_Name:{company['Car_Name'],[car_index]}')
print(f"Model:{company['Model'],[car_index]}")
print(f"Year:{company['Year'],[car_index]}")
print(f"Color:{company['Color'],[car_index]}")
# Out:
# Car_Name:(['BMW', 'Alto'], [0])
# Model:(['X8', 800], [0])
# Year:([2025, 2010], [0])
# Color:(['Black', 'Red'], [0])

# %%
company['Car_Name']
# Out:
# ['BMW', 'Alto']

# %%
company={'Car_Name':["BMW",'Alto'],"Model":['X8',800],'Year':[2025,2010],'Color':['Black','Red']}

# %%
company.items()
# Out:
# dict_items([('Car_Name', ['BMW', 'Alto']), ('Model', ['X8', 800]), ('Year', [2025, 2010]), ('Color', ['Black', 'Red'])])

# %%
index=1
car_details={a:b[index] for a,b in company.items()}

# %%
car_details
# Out:
# {'Car_Name': 'Alto', 'Model': 800, 'Year': 2010, 'Color': 'Red'}

# %%
greet="Good Morning"
print("Hello Ravish",greet)
name="guru"
# Out:
# Hello Ravish Good Morning

# %%
print(greet,"ravish")
# Out:
# Good Morning ravish

# %%
print("Hello",name,greet)
# Out:
# Hello guru Good Morning

# %%
print(f"hello Everyone {greet} Today is my First day in my Collage.")
# Out:
# hello Everyone Good MorningToday is my First day in my Collage.

# %%
print("hello Everyone",greet,"Today is my First day in my Collage.",sep="")
# Out:
# hello EveryoneGood MorningToday is my First day in my Collage.

# %%
company={'Car_Name':"BMW","Model":'X8','Year':2025,'Color':'Black'}
if 'Model' in company:
    print("Yes, model key is available")
else:
    print("Not Available")
# Out:
# Yes, model key is available

# %%
company={'Car_Name':"BMW","Model":'X8','Year':2025,'Color':'Black'}
company.update({'Year':2030})

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8', 'Year': 2030, 'Color': 'Black'}

# %%
company={'Car_Name':"BMW","Model":'X8','Year':2025,'Color':'Black'}
company['Price']=50000000

# %%
company
# Out:
# {'Car_Name': 'BMW',
#  'Model': 'X8',
#  'Year': 2025,
#  'Color': 'Black',
#  'Price': 50000000}

# %%
company.pop('Price')
# Out:
# 50000000

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8', 'Year': 2025, 'Color': 'Black'}

# %%
company.pop('Color')
# Out:
# 'Black'

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8', 'Year': 2025}

# %%
company.popitem()
# Out:
# ('Year', 2025)

# %%
company
# Out:
# {'Car_Name': 'BMW', 'Model': 'X8'}

# %%
del company['Model']

# %%
company
# Out:
# {'Car_Name': 'BMW'}

# %%
company.clear()

# %%
company
# Out:
# {}
