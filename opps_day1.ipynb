# %% [markdown]
# File Handling:-

# %%
a=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r")
b=a.read()
print(b)
a.close()
# Out:
# Hello

# %%
b
# Out:
# 'Hello'

# %%
a=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","w")
b=a.write("Hello, This is Vishnu learning file handling in python.\n I am enjoying it a lot.\n Today is a good day to learn something new.")
print(b)
a.close()
# Out:
# 125

# %%
f=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r")
x=f.readline()
b=f.readline()
c=f.readline()
f.close()

# %%
x,b,c
# Out:
# ('Hello, This is Vishnu learning file handling in python.\n',
#  'I am enjoying it a lot.\n',
#  'Today is a good day to learn something new.')

# %%
print(x,end="")
print(b,end="")
print(c,end="")
# Out:
# Hello, This is Vishnu learning file handling in python.
# I am enjoying it a lot.
# Today is a good day to learn something new.

# %%
y=b
z=c

# %%
print(y,z,sep=" ")
# Out:
# Today is a good day to learn something new. Today is a good day to learn something new.

# %%
f=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r")
a=f.readlines()
print(a)
f.close()
# Out:
# ['Hello, This is Vishnu learning file handling in python.\n', 'I am enjoying it a lot.\n', 'Today is a good day to learn something new.']

# %%
a[2]
# Out:
# 'Today is a good day to learn something new.'

# %%
f=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","w")
b=f.write("Hello, This is Vishnu learning file handling in python.\n I am enjoying it a lot.\n Today is a good day to learn something new.")
print(b)
f.close()
# Out:
# 125

# %%
f=open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","a")
b=f.write("\n Hello,Everyone, Welcome to file handling in python.")
print(b)
f.close()
# Out:
# 53

# %% [markdown]
# With

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r") as f:
    a=f.read()
    print(a)
# Out:
# Hello, This is Vishnu learning file handling in python.
#  I am enjoying it a lot.
#  Today is a good day to learn something new.
#  Hello,Everyone, Welcome to file handling in python.

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","a") as f:
    b=f.write("File handling in python is very easy and fun to learn.")
    print(b)
# Out:
# 54

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r+") as f:
    print(f.read())
    f.write("\n This is added using r+ mode.")
# Out:
# Hello, This is Vishnu learning file handling in python.
#  I am enjoying it a lot.
#  Today is a good day to learn something new.
#  Hello,Everyone, Welcome to file handling in python.File handling in python is very easy and fun to learn.

# %% [markdown]
# File Pointers in Python
# In Python, a file pointer is a marker that indicates the current position in a file where the next read or write operation will occur. When you open a file, the file pointer is typically positioned at the beginning of the file. As you read from or write to the file, the file pointer moves accordingly.

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r") as f:
    f.read()
    print(f.tell())
# Out:
# 282

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","a+") as f:
   
    f.write("\n This is added using a+ mode.")
    f.seek(82)
    print(f.read())
# Out:
#  Today is a good day to learn something new.
#  Hello,Everyone, Welcome to file handling in python.File handling in python is very easy and fun to learn.
#  This is added using r+ mode.
#  Hello
#  01234
#
#
#  This is added using a+ mode.
#  This is my 11 row
#  This is added using a+ mode.
#  This is added using a+ mode.
#  This is added using a+ mode.

# %%
with open(r"C:\Users\Vishnu\Desktop\Python_Full Stack\File_handling.txt","r")as f:
    a=f.readlines()
    print(a[3::])
# Out:
# [' Hello,Everyone, Welcome to file handling in python.File handling in python is very easy and fun to learn.\n', ' This is added using r+ mode.\n', ' Hello\n', ' 01234\n', '\n', '\n', ' This is added using a+ mode.\n', ' This is my 11 row\n', ' This is added using a+ mode.\n', ' This is added using a+ mode.\n', ' This is added using a+ mode.']

# %%
len(a)
# Out:
# 13

# %%
a[9]
# Out:
# ' This is added using a+ mode.\n'

# %%
print(20/10)
print(10/0)
# Out:
# 2.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 print(20/10)
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Basic Syntax

# %%
try:
    #risky COde
except:
    # error Handling Code

# %%
try:
    a=10
    b=0
    print(a/b)
except:
    print("Hey, You are dividing by zero. This is not allowed.")
print("I am outside the try except block.")
# Out:
# Hey, You are dividing by zero. This is not allowed.
# I am outside the try except block.

# %%
a=10
b=0
print(a/b)
print("I am outside the try except block.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#       4 print("I am outside the try except block.")
#
# ZeroDivisionError: division by zero

# %%
try:
    pin=int(input("Enter your pin: "))
    print("You entered pin is:",pin)
except:
    print("Invalid Pin, Numbers Only")
# Out:
# Invalid Pin, Numbers Only

# %%
pin=int(input("Enter your pin: "))
print("You entered pin is:",pin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pin=int(input("Enter your pin: "))
#       2 print("You entered pin is:",pin)
#
# ValueError: invalid literal for int() with base 10: 'wssss'

# %%
try:
    x=int("abc")
except ValueError:
    print("Invalid Input, Cannot convert string to integer.")
# Out:
# Invalid Input, Cannot convert string to integer.

# %%
x=int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x=int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
    x=int("33")
    print(x)
except ValueError:
    print("Invalid Input, Cannot convert string to integer.")
# Out:
# 33

# %%
Common Python Errors:
    Error name              kb Aata hai
    ZeroDivisionError     Jab hum kisi number ko zero se divide karte hain.
    ValueError            Jab hum kisi incompatible type ko convert karne ki koshish karte hain.  int("abc")
    TypeError             Jab hum kisi function ko galat type ke argument dete hain. "10"+5
    IndexError            Jab hum kisi list ya string me aise index pe access karne ki koshish karte hain jo exist nahi karta.
    KeyError              Jab hum dictionary me aise key se access karne ki koshish karte hain jo exist nahi karti.

# %%
z="10"
b=4
print(z+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 z="10"
#       2 b=4
# ----> 3 print(z+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a=(20,50,60)
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 a=(20,50,60)
# ----> 2 print(a[3])
#
# IndexError: tuple index out of range

# %%
try:
    a=int(input("Enter a number: "))
    print(10/a)
except ZeroDivisionError:
    print("Division by zero is not allowed.")
except ValueError:
    print("Sirf Number Daalo")
# Out:
# Sirf Number Daalo

# %%
try:
    a=int(input("Enter a number: "))
    print(10/a)
except:
    print("An error occurred.")
else:
    print("Program Suceesfully executed.")
# Out:
# An error occurred.

# %%
try:
    f=open(r"C:\Users\Vishnu\Desktop\passwordd.txt")
    print(f.read())
except:
    print("File is not Available")
finally:
    print("Execution Completed")
# Out:
# File is not Available
# Execution Completed

# %%
try:
    f=open(r"C:\Users\Vishnu\Desktop\passwdord.txt")
    print(f.read())
except:
    print("File is not Available")
# Out:
# File is not Available

# %%
try:
    f=open(r"C:\Users\Vishnu\Desktop\passwordd.txt")
    print(f.read())
    f.close()
except:
    print("File is not Available")
finally:
    print("Execution Completed")
# Out:
# File is not Available
# Execution Completed

# %%
try:
    pin=int(input("Enter your pin: "))
    print("Transcation Processing")
except:
    print("Invalid Pin, Numbers Only")
finally:
    print("Please Take Your Card Back")
# Out:
# Transcation Processing
# Please Take Your Card Back
